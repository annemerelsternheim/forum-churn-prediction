# %%
#----------IMPORTS------------
import json, re
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint
from pattern.nl import sentiment
from collections import defaultdict
from matplotlib.backends.backend_pdf import PdfPages

#-----UNBOUND VARIABLES-------

#----------CODE---------------

plt.close()
print('plots closed')

file = json.load(open('C:\\Users\\sternheimam\\Dropbox\\TNO\\Scriptie\\4. Data\\viva_forum_latest_summarized.json'))
testsent=(file[0:2000])
print('file loaded')
# Out:
# plots closed
# file loaded

# %%
#make list of triples (author, sentiment, questionmarks) for each line of text
def annotated_data(data):
    # bound variables
    name = ''
    sentim = 0
    polarity = 0
    polcount = 0
    questionmark = 0
    authorlist = []
    linecount=0

    for line in data:
        print linecount
        name=line['author']
        if isinstance(line['text'],unicode):
            print(line['text'])
            polarity += sentiment(line['text'])[0]
            polcount+=1
            if re.search('\?',line['text'][0]): 
                #print linecount
                #print(line['text'])
                questionmark+=1
        elif isinstance(line['text'],list):
            for textfeatures in line['text']:
                print(textfeatures['sentence'])
                polarity += sentiment(textfeatures['sentence'])[0]
                polcount+=1
                if re.search('\?',textfeatures['sentence'][0]):
                    #print linecount
                    #print(textfeatures['sentence'])
                    questionmark+=1
        sentim = polarity/polcount
        authorlist.append((name,sentim,questionmark))
        questionmark=0
        polarity=0
        polcount=0
        linecount+=1
    print('authorlist generated')
    return(authorlist)

# %%
# I do not know how to make the list of triples into a dictionary containing two lists as value in ONE step,
# so I make two dictionaries and combine those into one..

def make_dictionary(authorlist):
    author_sent = defaultdict(list)
    author_ques = defaultdict(list)
    for name, s_val, q_val in authorlist:
        author_sent[name].append(s_val) 
        author_ques[name].append(q_val)
    print('dictionaries generated')

    all_dict = defaultdict(list)
    for key in author_sent.keys():
        all_dict[key].append((author_sent[key]))
    for key in author_ques.keys():
        all_dict[key].append(author_ques[key])
    print('dictionaries combined')
    return(all_dict)

# %%
# Present the data. Here, I make a plot for every user, over time.
# also save to pdf
def plots_by_author(all_dict):
    pp = PdfPages("plots-author.pdf")
    for name in all_dict.keys():
        fig, ax1 = plt.subplots()
        ax2 = ax1.twinx()

        ax1.plot(all_dict[name][0], 'g-', alpha=0.5) # green = sentiment
        ax2.plot(all_dict[name][1], 'r-', alpha=0.5) # red = question marks
        ax1.set_ylabel('Sentiment', color='g')
        ax2.set_ylabel('Question Marks', color='r')

        ax1.set_ylim(-1,1)
        ax2.set_ylim(-5,5)
        plt.title(name)
        
        figur=plt.figure(1)
        plt.show()
        pp.savefig(figur, dpi = 300, transparent = True)
    pp.close()

# %%
# Present the data differently: Here I make a plot for every variable.
# I doubt whether it provides a lot of insight, as I expect that every patient needs different amounts of time to get empowered by the forum
# therefore, empowered and disempowered patients probably level each other out.
# In any case I got to experiment with line plots and scatter plots and trend lines.

def scatter_plots_by_variable(all_dict):
    pp = PdfPages("plots-variable.pdf")
    j=0
    for j in range(len(all_dict.values()[0])):

        plotlist=[]
        lenlist=[]
        listlist=[]
        
        i=0
        while i>=0:
            somelist=[]

            for name in all_dict:
                if len(all_dict[name][j])>i:
                    somelist.append(all_dict[name][j][i])
                    #print(somelist)
                else:
                    #print(len(all_dict[name][j]),'<',i)
                    pass
            if len(somelist) == 0:
                break
            else:
                listlist.append(somelist)
                plotlist.append(np.mean(somelist))
                lenlist.append(len(somelist))
                i+=1

    # plots showing means per post and trend lines  
        plt.close()        
        fig, ax1 = plt.subplots()
        ax2 = ax1.twinx()

        x = np.array([i for i in range(len(plotlist))])
        y = plotlist

        ax1.scatter(x,y,s=5, color='green',alpha=0.6) # green = sentiment
        ax2.plot(lenlist, 'r-', alpha=0.2) # red = question marks

        fit = np.polyfit(x, y, deg=1)
        ax1.plot(x, fit[0] * x + fit[1], 'b-', alpha=0.8)

        ax1.set_ylabel('Mean', color='g')
        ax2.set_ylabel('Frequency', color='r')
        ax1.set_xlim(0,)

        if j==0:
            ax1.set_ylim(0,1)
            ax2.set_ylim(0,15)
            plt.title('Mean sentiment per post')
        else:
            ax1.set_ylim(0,6)
            ax2.set_ylim(0,15)
            plt.title('Mean nr of question marks per post')
        j+=1
        
    # scatter plot of all measured values
        n=0
        for lists in listlist:
            for elements in lists:
                ax1.scatter(n,elements, color='blue', s=3, alpha=0.4) # adjusting s to s=len(lists) changes the size of the dots respective to the nr of measurements. would be cool to do with means
            n+=1
        figur=plt.figure(1)
        plt.show()
        pp.savefig(figur, dpi = 300, transparent = True)
    pp.close()

# %%
authorlist=annotated_data(testsent)
all_dict=make_dictionary(authorlist)
#plots_by_author(all_dict)
#scatter_plots_by_variable(all_dict)
# Out:
# 0
# Om maar te beginnen, ik ben hypochonder. Ben er op dit forum ook al eens op gewezen dat het niet de oplossing is mijn klachten hier neer te zetten...      Maar heb nu iets waarvan ik dus echt niet weet wat ik ermee moet.      Op de zijkant van mijn linkerborst is een verkleuring van ca. cm te zien in de huid. De verkleuring is niet rood, meer wat donkerder dan mijn eigen huidskeur.      Ik smeer er vaseline op, omdat ik dacht dat het een droog vlekje is.. maar het gaat dus niet weg.. De verkleuring blijft.      Het de assistente gebeld van de huisarts en die stelde me gerust.. Maar ik maak me zorgen....... over .... borstkanker...      Hoe kijken jullie hier tegenaan... Ik durf het thuis met niemand te bespreken.. ze worden gek van mijn angsten...
# 1
# O ja, en hoe meer ik erop let, hoe erger en duidelijker de vlek natuurlijk lijkt..
# Mijn man heeft er vanochtend wel even naar gekeken en zei dat er gewoon een verkleuring van huid zichtbaar was niet iets om me zorgen over te maken...
# 2
# Grietje....
# kom op!
# Schop jezelf onder je kont!!
# Sterkte, meid!
# 3
# Tsja, mijn hele lichaam zit onder de moedervlekken/verkleuringen etc.
# Het hoort erbij.
# Op veel foto's in de bladen worden alle oneffeheden weggepoetst en zie je het dus niet, maar iedereen heeft wel wat.
# Ben je al onder behandeling voor je angsten?
# 4
# Lieve Grietje,    Bel morgen de huisarts dat je het toch even wil laten bekijken, hij kan je echt geruststellen wij hier niet.
# Verder ken ik die angsten en ik weet niet hoe erg ze zijn maar praat er eens over met een professional.
# Vaak hangen de angsten om dood te gaan en om ziektes te krijgen namelijk samen met een levensangst.
# Om het beste uit je eigen leven te halen.
# Blijf niet zitten met dit soort angsten uiteindelijk kunnen ze je levensgeluk vergallen en kom je daar pas over 10 tallen jaren achter en die tijd kan je nooit meer terughalen.
# Liefs      PS hoe ouder je gaat worden hoe meer verkleuringen je krijgt op je lichaam.
# 5
# Jufdoortje..
# Dat is heldere taal..
# Bedankt alvast.
# Heb het toch nodig om de beoordeling van andere ´gewone´ mensen te lezen..
# Sinds ik vrij ben zijn mijn angsten sterker geworden..
# Maar ik ga in elk geval niet meer direct naar de arts toe en google ook niet meer dagelijks...
# Ben alleen nog wel bij tijd en wijle heel bang...
# Alsof een angst meester van me wordt.
# Heb zojuist 2 alprazolampilletjes genomen die er in het komende halfuur hopelijk voor gaan zorgen dat mijn angstgevoel vermindert en mijn verstand de overhand krijgt.
# 6
# Tsja.
# wat moet ik zeggen.
# Het is geen symptoom van borstkanker zover als ik weet, dus ik zou me er niet druk om maken, misschien een beugelbh die daar net een beetje schuurt?
# 7
# Donderdag ga ik weer naar de psycholoog.
# Ik heb een dijk van een angststoornis zoals de huisarts dat noemde.
# Maar ben reeds 5 maanden onder behandeling.
# Wat heb ik gewonnen?
# Perioden dat ik me nergens druk over maak...
# Niet meer elk weekend in doodsangst bij de huisartsenpost zitten...
# Maar ben er nog lang niet.
# Durf de huisarts niet te bellen.
# Ben juist vorige week langsgeweest ivm jeuk op mijn lichaam...
# Wat trouwens met vaseline weg is..
# Mijn huisarts weet van mijn stoornis af en ik schaam me enorm ervoor en durf niet te vaak naar haar toe.
# 8
# Grietje, je geeft zelf eigenlijk al aan waar het probleem ligt bij jou.
# Je bent hypochonder.
# Daardoor kunnen wij jou niet helpen, denk ik.
# Toch een poging wagen...
# Heeft je oma, tante moeder of zus borstkanker op jongere leeftijd gehad?
# Zo nee...
# Ik denk dat het meevalt.
# Verkleuringen komen vaker voor en zijn meestal onschuldig.
# De pigmentarie is dan gewoon iets anders.
# Maar goed dat je de huisarts hebt gebeld, dan weet je het zeker.
# 9
# Oh en heb je dat goede schema dat je laastst poste toegepast?
# 10
# Tsja.
# Ik heb de assistente gebeld...
# Als ik mijn naam zeg dan weten ze al dat ik het ben....
# De assistente heeft geprobeerd mij gerust te stellen.
# Zouden deze mensen voldoende geschoold zijn om in te kunnen schatten wanneer iets ernstig is en wanneer niet?
# Of is dat ook een hypochondergedachte?
# Verder is mijn man verpleegkundige, maar kan ook hij mij niet geruststellen..
# Sterker nog...
# als ik bij een arts ben geweest ben ik even gerustgesteld, maar lijkt het alsof de angst daarna erger terugkomt.
# Dit komt ook omdat bij mijn man enige jaren geleden een verkeerde diagnose gesteld is..
# 11
# @Borderwalk.
# Ik heb het gedaan..
# Maar ik weet niet wat de signalen van borstkanker zijn, dus heb ik het gevoel dat ik maar wat doe...
# Maar ik heb het als volgt gedaan.
# 1\.
# Ik heb een verkleuring op de huid van mijn borst.
# Zou het borstkanker kunnen zijn?
# Ik geloof dat voor 80%      2\.
# Wat adviseer ik een vriendin met deze klachten?
# Ik zou haar de huisarts laten bellen als ze zich zorgen maakt.
# Als de assistente zegt dat het niets is moet je daarop kunnen vertrouwen.
# 3\.
# 100 mensen geven mij aan dat angst een signaal is.
# Ik heb nu de tijd om na te denken en rust en daarom zijn mijn angsten wat erger.
# Het is niets anders dan een uiting van mijn stoornis..
# Het is geen re- ele gedachte.
# 4\.
# Omdraaiing    \- Ik ben kerngezond.
# 5\.
# Alternatieve verklaring    \- Ik heb tot 2 maanden geleden borstvoeding gegeven en mijn dochtertje krabde mij soms per ongeluk.
# Wie weet is het een verkleuring daarvan.
# \- Ik denk dat de verkleuring erger is dan die werkelijk is, omdat ik hypochonder ben en erop gefocussed.
# \- Mijn huid is gewoon wat droog, verkleuring kan overal voorkomen.
# \- De assistente heeft je gerustgesteld, niet alle assistenten en artsen maken fouten.
# Als het iets ergs zou kunnen zijn zou ze me hebben gezegd een afspraak te maken.
# 12
# Grietje81 er nog nooit iemand doodgegaan aan een verkleuring op de huid van 1 cm.
# 13
# Ik ben doktersassistente, en je mag ervan uit gaan dat de assistente voldoende geschoold is ja.
# Zij heeft een protocollenlijst die ze moet volgen, en daarnaast ervaring.
# Ze moet bijscholingen volgen om up to date te blijven.
# Maar, wat een assistente ook leert is om bij grote angst van de patiënt een consult af te spreken bij de huisarts.
# Omdat telefonisch gerust stellen soms niet werkt.
# Daarom kan je beter vragen om een consult als je zo bang blijft.
# Heeft je huisarts telefonisch spreekuur?
# Zou dat een oplossing voor je zijn?
# 14
# Grietje heb je naast de psych ook nog andere vormen van ondersteuning?
# Ik heb een mindfulness training gedaan en die heeft mij erg goed geholpen bij mijn angststoornis.
# 15
# Ik vind het lief dat jullie hier reageren op mijn topic.
# Hoewel ik verwacht dat jullie echt denken: die meid is knettergek...
# Toch ontzettend bedankt..
# Hierdoor voel ik me niet zo alleen en heb ik het gevoel dat mijn angsten door jullie nuchterheid wat minder worden.
# 16
# @Georgette.
# Vorige week heb ik heeft de assistente me inderdaad op een spoedplek gezet, omdat ik erg angstig was vanwege jeuk op mijn lichaam.
# Er zijn verschillende assistenten.
# Een ervan wimpelt me altijd af en ik heb het gevoel dat ik me aanstel als ik haar aan de lijn krijg.
# De andere twee zijn begripvol.
# De assistente die ik vandaag sprak is ervaren.
# Mijn huisarts heeft telefonisch spreekuur ja..
# Maar met zichtbare plekken ga ik, als ik ga, er toch liever heen.
# @Tikker.
# Ik heb vorige week vrijdag een eerste consult bij een haptotherapeut gehad.
# Was erg confronterend en mijn angsten zijn sindsdien aangewakkerd.
# 17
# Ik heb vaak verkleuringen, omdat ik me bijvoorbeeld een beetje gestoten heb, die worden dan niet blauw, want zo hard was het niet, maar zijn wel een verkleuring.
# Daarnaast krijg ik onder invloed van hormonen pigmentvlekken.
# Jij heb net een kindje gehad?
# Het kan zijn dat het een pigmentvlek is, die door de hormonale verandering vaker voorkomen.
# Dit zijn veel vaker voorkomende situaties en in 99% van de gevallen de juiste verklaring voor jouw symptoom.
# Ik vind je niet zo zeer knettergek als dat het mij gewoon heel vervelend lijkt als je zulke angsten hebt.
# 18
# Niet aardig dat die ene assistente jou afwimpelt.
# Dat hoort niet, het is haar werk om jou een beter gevoel te geven na een telefoongesprek.
# Ook hypochondrie wordt behandeld op onze opleiding.
# Maar ik zou er echt proberen vanuit te gaan dat ze weten waar ze het over hebben.
# Ze zijn er om jou te helpen.
# En als je erg ongerust bent, jou toch een afspraak met de huisarts te geven.
# 19
# @ Grietje81'      Ik heb zelf een angststoornis en ik kan me dus erg goed verplaatsen in je verhaal.
# Je bent niet gek!
# Ik ben nu trouwens wel erg benieuwd naar dat schema waar je het over hebt.
# In welk topic staat het?
# 20
# Hallo Lolapaloeza,      Mijn kindje is al 3.
# Ik heb haar lang bv gegeven.
# Maar ben 3 maanden geleden gestopt met bv omdat ik een andere zwaardere anticonceptiepil ging gebruiken waarbij bv werd afgeraden.
# Ook de combi met alprazolam vond ik niet goed.
# Sindsdien ook op hetzelfde moment in mijn cyclus pijnlijke borsten, maar daar maak ik me geen zorgen over.
# Ik heb mijn borst niet gestoten trouwens...
# De angsten zijn heel vervelend.
# Het lijkt alsof er iets anders sterkers overmacht over me heeft op dat moment, de angst dus.
# Ik wil ook zo graag beter worden en niet meer zo bang zijn..
# 21
# Ik heb het schema gepost om 17.
# 50 uur hier in dit topic.
# Het is cognitieve gedragstherapie die leert dat je ook op een andere manier ergens naar zou kunnen kijken.
# 22
# > quote:  >  > **[Grietje81 schreef op 27 december 2010 @ 17:58](    @Tikker.
# Ik heb vorige week vrijdag een eerste consult bij een haptotherapeut gehad.
# Was erg confronterend en mijn angsten zijn sindsdien aangewakkerd.
# Wat vervelend voor je !
# [:hug:] Bespreek dat wel met je psych en je hapterapeut misschien gaat het te snel en val jij alleen maar harder in je paniek.
# Lukt het je misschien om tegen jezelf te zeggen dat het helemaal niet gek is dat je nu angstig bent omdat je een heftige sessie hebt gehad.
# Dat het gevoel vervelend is en dat het er mag zijn?
# Ik zal je een persoonlijk voorbeeld geven: ik had vorige week een spannend gesprek.
# Na zo'n gesprek heb ik te veel spanning opgebouwt en dat komt er bij mij middels paniek uit.
# Ik krijg dan bijvoorbeeld hoofdpijn en daar wordt ik angstig van, o jee misschien zit het wel fout in mijn hoofd, ik ga vast dood!
# Ik ben in staat om mijn spanningsveld te herkennen en dus even rustig ergens te gaan zitten en denken oke.
# Ik denk dus dat ik zo dood ga, hoe groot is die kans?
# Kan het ook zijn dat het komt door het gesprek van vanmiddag?
# Ja dat kan eigenlijk wel.
# Nou laat maar even komen dan, gaat zo wel weer weg.
# En het gaat het ook weg.
# Rustig ademhalen, lief zijn voor jezelf en laat het maar even zo zijn.
# Wat is jouw grootste angst?
# 23
# @aarbei923, wat voor angststoornis heb je en hoe lang al?
# Wat doe je eraan?
# Volgens mijn psychiater heb ik al veel vorderingen gemaakt, omdat ik redelijk functioneer in een half jaar tijd..
# Hij zegt dat ik dat moet zien en dat ik van mijzelf moet zien dat ik het goed doe..
# Maar ik ben zo bang dat ik altijd wel met een vorm van angst moet leven..
# of in elk geval perioden.
# Hypochondrie is volgens mij niet gemakkelijk te behandelen..
# SOms is het doel alleen maar dragelijk maken.
# 24
# > quote:  >  > **[Grietje81 schreef op 27 december 2010 @ 18:09](    Ik heb het schema gepost om 17.
# 50 uur hier in dit topic.
# Het is cognitieve gedragstherapie die leert dat je ook op een andere manier ergens naar zou kunnen kijken.
# Oke !
# [:\)].
# Dankje.
# Lijkt me erg handig als 'eye opener'!
# 25
# @ Tikker.
# Mijn grootste angst is doodgaan en de angst dat ik geen enkele vorm van bewustzijn meer heb.
# Dat er een nooit meer is zeg maar..?
# En mijn grootste angst is dat de artsen een waarschijnlijkheidsdiagnose stellen en dat die, net als bij mijn man, ook niet klopt.
# Ik herken de relatie nu wel...
# In mijn gedragsschema zie je ook dat de 100 mensen mij vertellen dat het een signaal is en dat het dus kan komen door de haptotherapie.
# Met mijn verstand vertel ik mezelf dat dus inderdaad wel...
# , maar mijn angst is er toch...
# Hoe ga jij daarmee om?
# Hoe zorg je dat je verstand ook op een paniekmoment de overhand krijgt?
# Want zover ben ik nog niet..
# 26
# Verder ben ik bang controle te verliezen over vanalles.
# Is begonnen in 2007 toen ik opeens een kwartier niet meer kon praten...
# Ik was de controle over mijzelf kwijt.
# Toen is het ook bergafwaarts gegaan..
# Ben ik van angstperiode in angstperiode gegleden...
# 27
# Wie of wat zou jou wèl gerust kunnen stellen?
# 28
# @ Tikker.
# Ik heb in mijn leven nooit geleerd lief te zijn voor mijzelf.
# Ik ben seksueel misbruikt door een vertrouwenspersoon mijn hele jeugd.
# Heb voor mijn moeder gezorgd omdat ze naar de alcohol greep.
# Heb toen ik op kamers was zo veel verschillende wisselende contacten gehad (seks), omdat ik dacht dat ik daar liefde zou vinden ofzo...
# Het maakte me zelfverzekerd.
# Heb mijn moeder rond die tijd ingelicht over het misbruik, maar ze gaf aan dat als ik het kenbaar zou maken ik de hele familie kapot zou maken      Verder heb ik voor mijn man gezorgd, omdat hij heel ziek is geweest.
# ..
# en eigenlijk nog veel ziek..
# Ik moet dus inderdaad ook aangeven voor de pscych.
# wanneer ik denk over mijn grenzen te gaan..
# Ik ga naar de hapto omdat ik bang ben voor mijn eigen gevoel, bang ben dat ik me aanstel, en bang ben voor aanraking.
# Verder zit ik met een probleem.
# Ik voel me afhankelijk van de hulp die mijn hulpverlener mij biedt.
# Als er een week uitvalt, ben ik van slag...
# Ben zo bang dat ik te afhanelijk word van die hulpverlener...
# 29
# Grietje, ik heb een tijd geleden ook precies zo'n plekje gehad.
# Dat kwam doordat een beugel van mijn bh er steeds langs schuurde.
# na een paar weken was het weer wegetrokken.
# Daarnaast lijkt het me eigenlijk onmogelijk om je zorgen te maken om borstkanker, want dat heeft mi niets met de huid te maken.
# 30
# > quote:  >  > **[Grietje81 schreef op 27 december 2010 @ 18:11](    @aarbei923, wat voor angststoornis heb je en hoe lang al?
# Wat doe je eraan?
# Volgens mijn psychiater heb ik al veel vorderingen gemaakt, omdat ik redelijk functioneer in een half jaar tijd..
# Hij zegt dat ik dat moet zien en dat ik van mijzelf moet zien dat ik het goed doe..
# Maar ik ben zo bang dat ik altijd wel met een vorm van angst moet leven..
# of in elk geval perioden.
# Hypochondrie is volgens mij niet gemakkelijk te behandelen..
# SOms is het doel alleen maar dragelijk maken.
# Ik heb een gegeneraliseerde angststoornis.
# Ik heb mijn hele leven al last van angsten maar het is het laatste jaar veel erger.
# Een maand geleden pas heb ik van een psychiater gehoord dat het zo heet.
# Voor mij is het al een hele opluchting dat ik nu eindelijk weet wat het precies is en wat ik er aan kan doen.
# En dat ik niet gek ben.
# Mijn therapeut gelooft dat deze angsten aangewakkerd worden door veranderingen en dat als ik weer 'gewend' ben aan de situatie, ze vanzelf weer minder zullen worden.
# 31
# > quote:  >  > **[Grietje81 schreef op 27 december 2010 @ 18:21](    @ Tikker.
# Ik heb in mijn leven nooit geleerd lief te zijn voor mijzelf.
# Ik ben seksueel misbruikt door een vertrouwenspersoon mijn hele jeugd.
# Heb voor mijn moeder gezorgd omdat ze naar de alcohol greep.
# Heb toen ik op kamers was zo veel verschillende wisselende contacten gehad (seks), omdat ik dacht dat ik daar liefde zou vinden ofzo...
# Het maakte me zelfverzekerd.
# Heb mijn moeder rond die tijd ingelicht over het misbruik, maar ze gaf aan dat als ik het kenbaar zou maken ik de hele familie kapot zou maken      Verder heb ik voor mijn man gezorgd, omdat hij heel ziek is geweest.
# ..
# en eigenlijk nog veel ziek..
# Ik moet dus inderdaad ook aangeven voor de pscych.
# wanneer ik denk over mijn grenzen te gaan..
# Ik ga naar de hapto omdat ik bang ben voor mijn eigen gevoel, bang ben dat ik me aanstel, en bang ben voor aanraking.
# Verder zit ik met een probleem.
# Ik voel me afhankelijk van de hulp die mijn hulpverlener mij biedt.
# Als er een week uitvalt, ben ik van slag...
# Ben zo bang dat ik te afhanelijk word van die hulpverlener...
# Wat heb jij veel op je bord gekregen zeg !
# [:hug:]      Kan je dat laatste wat je schrijft, aangeven bij die hulpverlener?
# Misschien dat er dan bijv.
# even telefonisch contact mogelijk is om je gerust(er) te stellen?
# 32
# Dit is voor mij erg herkenbaar omdat mijn moeder hier ook aan lijdt.
# Het gaat inmiddels een stuk beter, je kunt er echt geheel of gedeeltelijk van herstellen, houd moed.
# Probeer inderdaad steeds met jezelf in gesprek erover te blijven: Is het een reële angst?
# Wat zijn mijn valkuilen?
# 33
# > quote:  >  > **[Grietje81 schreef op 27 december 2010 @ 18:16](    Verder ben ik bang controle te verliezen over vanalles.
# Is begonnen in 2007 toen ik opeens een kwartier niet meer kon praten...
# Ik was de controle over mijzelf kwijt.
# Toen is het ook bergafwaarts gegaan..
# Ben ik van angstperiode in angstperiode gegleden...
# Tot het afgelopen zomer zo erg was dat de huisarts mij wilde laten opnemen bij GGZ  Heeeeel herkenbaar ;).
# Ik ben aan het leren te accepteren dat je niet over alles controle kan hebben.
# En niet te veel denken natuurlijk...
# 34
# > quote:  >  > **[Grietje81 schreef op 27 december 2010 @ 18:16](    Verder ben ik bang controle te verliezen over vanalles.
# Is begonnen in 2007 toen ik opeens een kwartier niet meer kon praten...
# Ik was de controle over mijzelf kwijt.
# Toen is het ook bergafwaarts gegaan..
# Ben ik van angstperiode in angstperiode gegleden...
# Tot het afgelopen zomer zo erg was dat de huisarts mij wilde laten opnemen bij GGZ  Heeeeel herkenbaar ;).
# Ik ben aan het leren te accepteren dat je niet over alles controle kan hebben.
# En niet te veel denken natuurlijk...
# 35
# Mijn moeders ervaringen met een haptotherapeut waren overigens hetzelfde.
# Uiteindelijk is zij ermee gestopt maar dat wil natuurlijk niet zeggen dat het voor jou niet werkt.
# Probeer niet teveel op je bordje te leggen, één stap per keer is al heel wat!
# Het heeft tijd nodig om met alles te dealen.
# Misschien kun je in de toekomst nog bezig met het verwerken van je verleden door bijvoorbeeld psychotherapie maar bewaak je grenzen.
# Gebruik je ook angstremmers/antidepressiva?
# 36
# Dan hebben we ongeveer dezelfde angst.
# Heel vervelend en ik dacht ook dat het vast nooit meer weg zou gaan.
# Het gaat waarschijnlijk bij mij ook nooit meer 100% weg maar zoals het nu is kan ik er prima mee leven (en dat zei ik 2 maanden geleden echt niet).
# Zou EMDR ook niet iets voor jou zijn, naast je cognitieve gedragstherapie?
# Dat helpt je waarschijnlijk wel bij het verwerken van je negatieve ervaring met de diagnose van je man.
# Het is niet mijn bedoeling om op de stoel van de psych te gaan zitten trouwens.
# Omdat ik het zelf zo goed herken wil ik je graag helpen en wijzen op de mogelijkheden.
# Vind wel dat je enorm goed bezig bent.
# Je hebt enorme stappen gemaakt en ondanks terugvallen (zijn heel normaal) zal je steeds verder komen.
# Hoe ik zorg dat de paniek niet de overhand krijgt?
# Ik heb veel geleerd van de mindfulness.
# Dus aandacht hebben voor je ademhaling en even te ontspannen.
# En hééél eng...
# ik ga de angst aan.
# Ik ga zitten en onderga het en ondertussen rustig blijven door ademen.
# De echte aanval duurt namelijk nooit langer dan 1 a 2 minuten.
# De rest is allemaal de adrenaline en die krijg je ook het moeilijkst weg.
# Dat lukt me redelijk door te gaan wandelen of 20x de trappen op- en af te lopen, liedjes te gaan zingen etc.
# En als ik het echt hartstikke zat ben dan ben ik gewoon ook even helemaal niet stoer en duw ik er gewoon een valiumtabletje in.
# Dan geef ik me even gewonnen.
# 37
# Grietje81, ipv je constant bezig te houden met je stempeltje "ziektevrees" zou je je moeten bezighouden om daadwerkelijk van dat stempeltje af te komen......
# therapie?
# 38
# > quote:  >  > **[Gipsyheart schreef op 27 december 2010 @ 18:29](    Grietje81, ipv je constant bezig te houden met je stempeltje "ziektevrees" zou je je moeten bezighouden om daadwerkelijk van dat stempeltje af te komen......
# therapie?
# Niet de moeite genomen om dit topic goed door te lezen?
# 39
# Och Grietje ik weet niet hoe maar iemand moet jou gaan leren lief te zijn voor jezelf.
# Wat een grote rugzak draag je bij je.
# Ik vind je enorm dapper en ik zie de wilskracht om beter te worden.
# Vergeet niet dat je het hartstikke goed doet !
# 40
# > quote:  >  > **[Tikker schreef op 27 december 2010 @ 18:33](    Och Grietje ik weet niet hoe maar iemand moet jou gaan leren lief te zijn voor jezelf.
# Wat een grote rugzak draag je bij je.
# Ik vind je enorm dapper en ik zie de wilskracht om beter te worden.
# Vergeet niet dat je het hartstikke goed doet !
# [:hug:]  Helemaal mee eens!
# 41
# > quote:  >  > **[Grietje81 schreef op 27 december 2010 @ 17:50](    Mijn eerste stelling geloof ik nu voor 65%        Dus ondanks de doktersassistente en het schema geloof je nu nog steeds dat het waarschijnlijker is dat je borstkanker hebt, dan iets onschuldigs zoals een droog/BHschuur/stoot/krab/pigmentplekje?
# Lastig hoor.
# Ik weet niet hoe ik je zou moeten geruststellen.
# Als je zou willen weten wat iemand zonder ziektevrees zou doen; Eerlijk gezegd zou zo'n kleine verkleuring op die plek mij waarschijnlijk nooit zijn opgevallen, tenzij het zou jeuken in welk geval ik het aan "die ene kanten bh" zou wijten.
# 42
# Kan je het schema nog eens herhalen?
# edit: dit vraag ik omdat iemand die ik ken, ook voor een bepaalde angst schema's af moet lopen om na te gaan hoe gegrond de angst is.
# Hoe vaker ze de schema's in zo'n situatie herhaald, hoe minder de angst wordt.
# Één keer zo'n schema langs lopen lijkt me in jouw geval eigenlijk niet genoeg.
# Ze heeft trouwens heel veel baat bij zogenoemde kloptherapie, ook wel EFT.
# ( [link]( ) Ik stond er sceptisch tegenover, maar ze heeft er al veel resultaat mee geboekt en het is een hulpmiddel wat je in situaties van angst meteen kan gebruiken om de angst te minderen en tot rust te komen.
# 43
# Het kan net zo goed een exceemvlekje of schimmeltje zijn...
# die zijn zeer goed te behandelen!
# 44
# Grietje, ik zat net te bedenken:      Je hebt al meerdere topics geopend waarin je aangaf dat je bang was dat je iets ergs zou hebben.
# In die topics bleek volgens mij telkens dat er niets aan de hand was.
# Kan je dat niet als steuntje gebruiken?
# Nu zit je weer met iets, kan je inzien dat het een heel reële mogelijkheid is dat dit alleen door je angst komt en het dus helemaal niets ernstigs is?
# 45
# Hallo,      Wat een reacties.
# Ik zal de vragen proberen te beantwoorden.
# @ Tikker, Aardbei923 en Klontje.
# Jullie reacties komen erg gemeend over.
# Ik herken ook delen van wat jullie schrijven.
# Ja, ik heb ook een angststoornis en ja die wordt aangewakkerd als ik de controle dreig te verliezen..
# In dit geval heb ik bij de hapto de controle over mijn emoties verloren, ik ben namelijk in huilen uitgebarsten.
# En ik heb mijzelf aangeleerd dat huilen een teken van zwakte is.
# Verder is mijn man van een hoge ladder afgevallen die dag, gelukkig viel alles mee, maar ik schrik vreselijk als ik over mijn man gebeld wordt.
# Ik heb EMDR therapie gehad.
# Maar dan voor een andere klacht, namelijk duizelingen.
# Het heeft eigenlijk niet dat gedaan wat ik ervan gehoopt had.
# Wat betreft de situatie met mijn man: ook hier geeft mijn psychiater aandacht aan.
# Ik doe cognitieve gedragstherapie, maar houd me ook bezig met ruimte creeren voor mijzelf, erovr nadenken wat ik leuk vind en erover nadenken wanneer ik denk me aan te stellen (omdat ik dus alsmaar doorga en mijn echte gevoel (moeheid bijv) niet meer voel of te laat).
# Ik houd dit alles bij in een boekje en neem dat elke week door met de psych.
# Nu ben ik bezig met het uitschrijven van duizelingen waar ik al jaren last van heb.
# Ik schrijf wat er gebeurt, wat mijn gedachten zijn en wat de gevolgen zijn.
# Hierdoor hoop ik inzicht te krijgen in wanneer ik over mijn grenzen ga.
# Verder vertel elke keer een stukje van mijn verleden.
# Dat ik met mijn zusje mijn moeder heb moeten verzorgen, mijn vader ging ervandoor met een ander en mijn moeder greep naar de fles, heb ik vorige week verteld.
# Ik ben ook veel bevestigd in niet tonen van emoties.
# Het is me niet in opvoeding meegegeven.
# Ik heb de scheiding van mijn ouders niet kunnen verwerken met verdriet, want er was niemand voor ons.
# Daarnaast moest ik sterk zijn voor mijn man die medisch opgegeven was.
# Verder heb ik kinderen, maar kan ik eigenlijk niet spontaan zwanger raken.
# Ik heb divere iui-behandelingen met hormonen ondergaan en een miskraam gehad voordat ik uiteindelijk zwanger raakte.
# Afgelopen april wilden we een derde kindje en zat ik volop in de ronde met injecteren...
# Ik heb halverwege de behandeling afgekapt omdat ik te veel last van angsten kreeg....
# Dus eigenlijk heb ik nog een kinderwens, maar die gaat niet meer in vervulling.
# Dat ga ik de volgende keer aan de psych.
# vertellen.
# De hapto.
# Ik moet daar volgens de psych.
# mijn grenzen duidelijk aangeven.
# De volgende afsraak is eind januari, geeft me de tijd om me erop voor te bereiden en de vorige afspraak te verwerken.
# De hapto heeft gelukkig wel contact gehad met de psych, dus hij weet dat ik er veel moeite mee heb wanneer mensen mij aanraken.
# Iemand zei iets over het schema, dat ik na het invullen nog steeds geloofde erin.
# Ik heb geleerd dat al geloof ik na het invullen maar 5% minder in mijn eerste angst, dat dat al een winst is.
# Het schema is als volgt:    1\.
# Vraag jezelf voor welke ziekte je bang bent en schrijf dat op.
# Schrijf erbij hoe bang je ervoor bent in %.
# Schrijf er ook bij welke bewijzen voor de aandoening je hebt.
# 2\.
# Stel een vriendin komt bij je met dezelfde klacht, wel advies geef je haar?
# 3\.
# In een zaal met 100 mensen, wat denken zij dat het is?
# Voor mij persoonlijk zijn deze mensen omgezet in mensen die mij waarschuwen dat angst een signaal is.
# 4\.
# Maak een omdraaiing en verzin er bijv.
# wat bewijzen voor.
# Bijv.
# ik ben kerngezond      5\.
# Verzin een alternatieve verklaring en verzin er bewijzen voor.
# Schrijf ook op hoe sterk je hierin gelooft.
# Ga nu weer terug naar de eerste gedachte en schrijf op hoe sterk je daarin gelooft.
# Ik moet dit schema niet meerdere malen per dag toepassen, maar 1 maal per dag maximaal.
# Verder moet ik me bezig houden met leuke dingen doen, ruimte voor mezelf cre-eren en proberen mijn grenzen te bewaken.
# Iemand vroeg naar medicatie.
# Ik gebruik geen antidepressiva.
# Ik heb dat in het verleden gebruikt en het ging daarmee goed.
# Het is minder gegaan na een paar maanden stoppen.
# De psych.
# is in eerste instantie niet voor AD.
# Wel gebruik ik angstremmers, alprazolam.
# 3 maal daags 1 tablet.
# De laatste maanden 2 maal daags 1.
# Bij hevige angst vandaag heb ik er vanmiddag 2 genomen.
# Over dat afhankelijke gevoel van de psychiater.
# Ik weet niet hoe ik dat moet interpreteren.
# Is dat goed of slecht?
# 46
# @ Klontje.
# Met mijn verstand zeg ik tegen mezelf dat mijn angststoornis de oorzaak is van mijn angsten.
# Het gaat heel stukje bij beetje beter.
# Dat wat jij zegt is mijn einddoel, maar ik bekijk het per paar maanden.
# Nu terugkijkend naar een half jaar geleden gaat het over het geheel beter, met dalen hier en daar.
# Hopelijk gaat het een halfjaar verder nog een stuk beter.
# Inmiddels heb ik een boek besteld over haptonomie..
# Op advies van de hapto.
# Misschien ga ik het daardoor meer begrijpen.
# Misschien is het ook veel, en psychiater en hapto..
# Maar ze zijn in contact met elkaar en ik wil zo graag van deze 'ziekte' af, koste wat kost.
# 47
# Grietje, ik vroeg er naar waarom je dat schema niet meerdere keren in kan vullen, omdat dat bij een vriendin juist erg goed helpt.
# De angst neemt elke keer iets af.
# Je schrijf dat 5% verminderde angst al een winst is, waarom mag je het schema dan niet meerdere keren maken en er zo meer 'winst' uit halen?
# Verder denk ik n.
# a.
# v.
# je laatste reactie dat het aangaan, toelaten en écht voelen van emoties en daar dan de juiste stappen bij nemen een groot deel van de oplossing kan zijn tot het verminderen van je angsten.
# Huilen bijvoorbeeld, is absoluut geen teken van zwakte, maar het 'loslaten' van iets, iets uiten door middel van tranen.
# Dat is de functie er van, als je dat nooit kwijt kan 'ontplof' je bijna.
# Misschien 'ontplof' jij door middel van zo'n angstaanval?
# Maar volgens mij ben je onwijs goed bezig als ik je zo lees, knap van je!
# 48
# > quote:  >  > **[Grietje81 schreef op 27 december 2010 @ 20:42](    @ Klontje.
# Met mijn verstand zeg ik tegen mezelf dat mijn angststoornis de oorzaak is van mijn angsten.
# Het gaat heel stukje bij beetje beter.
# Dat wat jij zegt is mijn einddoel, maar ik bekijk het per paar maanden.
# Nu terugkijkend naar een half jaar geleden gaat het over het geheel beter, met dalen hier en daar.
# Hopelijk gaat het een halfjaar verder nog een stuk beter.
# Inmiddels heb ik een boek besteld over haptonomie..
# Op advies van de hapto.
# Misschien ga ik het daardoor meer begrijpen.
# Misschien is het ook veel, en psychiater en hapto..
# Maar ze zijn in contact met elkaar en ik wil zo graag van deze 'ziekte' af, koste wat kost.
# Ik vind het heel moedig van je dat je je angsten aangaat dmv therapie!
# Uit eigen ervaring begrijp ik hoeveel moeite het kost, hoe zat je het soms bent maar dat je toch door moet gaan om er af te komen.
# In haptotherapie heb ik me een tijdje geleden ingelezen, het lijkt me juist heel goed voor je om jezelf wat meer open te kunnen stellen.
# Als je het gevoel hebt dat het teveel wordt, kan je dat met je psychiater bespreken?
# 49
# Is het trouwens geen idee om een eigen topic te openen?
# Waar je steun en geruststelling kunt krijgen en je, als je je rot of angstig voelt, de reacties terug kan lezen.
# En er met lotgenoten over kunt praten bijvoorbeeld.
# Misschien bestaat er zelfs wel zo'n topic?
# 50
# Ha Klontje,      Ik zal het toch eens gaan proberen...
# Misschien neemt bij mij de angst ook wel af als ik keer op keer het schema invul?
# Ik heb donderdag een afspraak met de psych.
# en dan zal ik eens vragen waarom mij geadviseerd is om per dag 10 minuten te nemen voor het uitwerken van een schema.
# Ik denk inderdaad dat het re-eel is dat mijn emotie zich reguleert via angst.
# Dat is althans ook de hypothese van de psych.
# Ik zie het ook meer en meer in.
# Van de hapto kreeg ik een schema mee.
# Als ik boosheid kan uiten, kan ik verdriet makkelijker uiten, en dat hangt dan ook weer samen met blijheid.
# Een van de emoties is angst, en die is bij wordt bij mij dus altijd aangezet.
# Maar een vraag: jouw vriendin vult dus bijvoorbeeld 3 keer na elkaar dat schema in?
# 51
# @Klontje.
# Ik heb een topic geopend onder 'psyche': vreselijke angst voor ernstige ziektes.
# Ik schrijf daar af en toe, maar er zijn de laatste tijd niet meer zoveel reacties.
# Eigenlijk zou ik veel ook moeten opschrijven in mijn schriftje voor de psych.
# 52
# Goed bezig hoor, complimenten!
# Mijn vriendin vult niet letterlijk een schema in, maar ze herhaald een serie van vragen die erg overeenkomen met jouw schema.
# Bijv:    \- ik voel angst, waarom voel ik dit?
# \- zijn er gegronde redenen waarom ik me zo voel/ wat zijn de feiten?
# \- als ik de feiten bekijk, voel ik dit nog steeds zo?
# Iets in die trant zeg maar, en door het een aantal keer te herhalen (inderdaad twee, drie keer) neemt de angst steeds iets meer af.
# Ze zegt dat het soms ook weleens helemaal niet helpt, omdat het dan gewoon echt niet lukt.
# Dan laat ze het ook even links liggen en probeert ze het later of de volgende dag.
# Die vriendin heeft veel gelijkenissen met wat jij beschrijft, maar het is voor iedereen natuurlijk anders wat wel of niet helpt.
# Ik wil je niet per ongeluk op een verkeerd spoor zetten, dus hou dat in de gaten he.
# 53
# Grietje ik vind dat je voor vandaag genoeg gedaan hebt.
# Je hebt je angst aangegeven en een heel gedeelte van je levensverhaal opgeschreven.
# Nu is het tijd om te rusten goed?
# Hoe is het met je angstgevoel op dit moment?
# Wat is het angstcijfer nu op een schaal van 1 tot 10?
# Ik denk ook dat het heel goed is voor je om hier van je af te schrijven en ervarings verhalen te horen en te delen.
# Maar verder moeten wij als forummers ook vertrouwen op jouw psych en psychiater.
# Ik wil je niet onnodig beinvloeden.
# Als je het fijn vindt mag je me altijd komen roepen.
# Ik ben dagelijks te vinden in het verveeltopic op de peiler "overig".
# Ik wil niet te moederig overkomen maar wil wel voorkomen dat je te hard gewerkt hebt vandaag en zo je angsten versterken.
# Als je wil dat ik me er niet mee bemoei mag je dat gewoon zeggen.
# 54
# Ha Tikker,      Wat ontzettend lief dat je zo reageert.
# Ja, ik heb genoeg gedaan vandaag.
# Ik heb zojuist het uitgewerke schema in het schrifje van de pscyhiater gezet.
# Ik heb erbij vermeld dat ik een hogere dosis angstremmers in heb genomen, de weg van de minste weerstand dus..
# Op dit moment voel ik me heel rustig..
# Maar wat wil je.
# NOrmaal gebruik ik savonds en smorgen 1 tabletje en 2 uur geleden heb ik er 2 tegelijk ingenomen.
# Zal de psych.
# ws niet blij mee zijn..
# Maar ik ben inderdaad soms zo moe van mijn eigen angst en wil gewoon genieten.
# Morgen neem ik gewoon weer de gewone dosis medicatie en desnoods vul ik het schema nogeens in .
# En lekker verjaardag vieren van mijn dochter.
# Je bemoeit en bemoedert niet, althans zo voelt het niet.
# Het voelt juist heel warm, je reactie.
# 55
# Mooie reactie Tikker, ben het er helemaal mee eens.
# Grietje, volgens mij heb je je er vandaag heel goed doorheen geslagen.
# Geniet van de verjaardag morgen en sterkte!
# 56
# Fijn want ik wil ook gewoon graag dat iedereen zich goed voelt.
# O en zet in je schriftje dat je stoer bent geweest.
# Dat je in zag dat het vandaag even te veel werd en dat je adequaat geweest bent om een extra pil in te nemen.
# Het is NIET de weg van de minste weerstand.
# Het is de weg naar zorgen voor jezelf en keuzes maken.
# Geniet enorm van de verjaardag van je dochter morgen!
# !
# 57
# Wil nu een paar dagen later toch nog even laten weten hoe het met me gaat.
# Ik heb erg genoten van de verjaardag van mijn dochter, maar voelde me niet echt goed: erg verkouden en spierpijn.
# Dit een paar dagen gehad en nu voel ik me weer beter, maar hebn ik nog een resthoestje.
# Maar, sinds een dag of 5 zie ik dat mijn rechter ooglid lager hangt dan mijn linker...
# Nu heb ik dit al wel vanaf april, maar het was van de zomer heel zichtbaar toen ik helemaal in de put zat.
# Nu heb ik me de afgelopen weken toch wat meer druk gemaakt over mijn gezondheid en ben ik ziek geweest en nu hangt mijn oog precies zo erg als van de zomer...
# Dit zorgt er bij mij voor dat ik last krijg van nog meer angst...
# Want ondanks dat ik gisteren een relaxdagje heb genomen en smiddags een dutje heb gedaan op de bank hangt mijn oog gewoon nog steeds....
# Mijn rationele gedachten proberen me gerust te stellen met zeggen:    \- Je had al wat meer angst, je bent ziek geweest.
# Dit alles heeft invloed op je gestel en je ooglid is al een zwakke plek..
# Die gaat hierdoor dus hangen.
# Het herstelt vanzelf wel weer.
# Maar als je je druk maakt erover kost dat ook weer extra energie.
# Maar het lukt me niet uit deze spiraal te komen.
# Vanmiddag toch naar mijn huisarts om mijn oog te laten zien..
# Ik hoop op een reactie van jullie, omdat jullie reacties mij gewoon heel goed doen.
# 58
# Ben natuurlijk veel te ongeduldig aan het wachten op een reactie...
# 59
# Dag Grietje,      Tenzij je ooglid minstens een cm lager hangt dan de andere zou het mij zeer waarschijnlijk nooit zijn opgevallen en had ik me er dus (voor mezelf) nooit druk over gemaakt...
# Vraagje aan jou en echt puur uit interesse...
# Waar ben je bang voor als je bijvoorbeeld naar je ooglid kijkt?
# Ik heb wel eens van hypochondrie gehoord, maar kan me er gewoon niets bij voorstellen...
# Vandaar mijn vraag.
# Ben je bang voor wat het is of ben je bang voor de gevolgen of een eventuele behandeling of...?
# Toch denk ik dat het goed is als je naar de dokter gaat.
# Al weet je waarschijnlijk zelf heel goed wanneer je wel of niet naar de dokter zou moeten gaan...
# Sterkte!
# 60
# Waar ben ik bang voor.
# In dit geval ben ik bang dat mijn ooglid zich niet herstelt en iets lager blijft hangen, als dat zo zou zijn zou ik bang zijn dat ik een ernstige spierziekte zou hebben.
# Hij hangt zo nu en dan ook wel eens een dagje wat meer..
# Maar nu is het extreem..
# Nu hangt hij al aan de binnenkant van mijn oog...
# vaker, als hij hangt, dan hangt hij wat af naar buiten toe.
# Ik heb een collega gevraagd of het opviel en haar reactie was: o ja, nu je het zegt..
# Maar het was me in eerste instantie niet opgevallen.
# 61
# Mijn ooglid hangt denk ik 2 mm lager.
# Maar het is zo zichtbaar omdat aan het andere oog de huid onder mijn wenkbrauw tot op mijn wimper hangt.
# En bij het hangoog is dat normaal ook wel zo, maar nu niet, nu zie je dus een stuk ooglid...
# 62
# Plus ik ben bang dat het wijst op een ernstige ziekte, waar ik dood aan ga.
# 63
# Heel reeel gedacht weet je dat de kans dat je iets ernstigs hebt heel erg klein is.
# Kun je dan niet denken 'ik zie wel wat er op me af komt, ik ben nu niet ziek en daar ga ik flink van genieten'?
# (ik weet niet precies hoe ik het moet opschrijven/zeggen, hopelijk begrijp je wat ik bedoel (maak je pas druk als het daadwerkelijk nodig is)).
# Even bagataliseren; stel dat je doodgaat, hoe erg is dat dan...?
# Ik bedoel dit niet beledigend of gemeen ofzo, maar ik ben bijvoorbeeld zelf niet bang om dood te gaan.
# Nu ben ik daar waarschijnlijk niet zoveel mee bezig als jij, dus is het makkelijk zeggen.
# Maar toch, kun je de boel voor jezelf niet wat 'lichter' maken?
# Overigens heb ik niet de illusie jou nu ff van je 'probleem' af te helpen hoor, ik vraag het me gewoon allemaal oprecht af...
# 64
# Ik heb ook last van een hangend ooglid.
# Als ik moe ben wordt dit ook veel erger.
# Waarschijnlijk ben je gewoon nog een beetje moe van de verjaardag van je dochter en je verkoudheid en oud en nieuw etc?
# 65
# Bedankt voor je reactie.
# Ik schrijf hier ook niet omdat ik wil dat mensen mij van mijn probleem afhelpen.
# Ik schrijf omdat het voor mij een uitlaatklep is en ik hier op dit forum tot nu toe eerlijke reacties heb ontvangen, waardoor het daarna altijd een stukje beter met me gaat.
# Ik beschouw jullie als de re- ele mensen die mij een beetje uit mijn pure angst halen, want mijn angstgedachten zijn vaak niet re-eel.
# Ik ben bang voor de dood.
# Ik ben er minder mee bezig dan een half jaar geleden, maar ik ben bang voor het GROTE niets.
# 66
# Nu ik de reactie van Marylin lees bedenk ik me ineens dat je het bij mi jook aan mijn ogen kunt zien als ik moe ben of ziek ben (geweest).
# Het ene ooglid hangt net iets meer dan het andere.
# Maar een ander ziet het niet en ik heb hiervoor nog nooit de link gelegd met een ernstige spierziekte...
# 67
# Het GROTE niets...
# Hm maar als het niets is dan merk je er toch ook niets van...?
# 68
# Toch geruststelling van jullie.
# Mijn verstand zegt me dat het inderdaad komt door ziekte en dat het nu langer blijft hangen omdat ik me er ook nog eens druk over maak....
# Heb er vanacht niet zo goed van geslapen.
# Euh ja..
# moeilijk uit te leggen..
# Ben bang dat er niets meer is...
# juist een hele enge gedachte dat ik NIETS meer merk..
# dat mijn bewustzijn er niet meer is.
# Kortom, ik hang denk ik erg aan het leven.
# Maar wel heel lief dat jullie mij geruststellen.
# 69
# Er is nog iets waar ik me voor schaam..
# maar toch maak ik me er druk over.
# Deze vakantie merkte ik al dat ik meer gefocussed ben op mijn lichaam.
# Nu ging ik na de kerstdagen op de weegschaal staan met het idee dat ik minstens 1,5 kg was aangekomen...
# Maar ik was dus 1 kg afgevallen!
# Ik zou juist blij moeten zijn, maar de hypochonder in mij roept natuurlijk het woord: 'kanker' .
# Ik kan me voorstellen dat velen die dit lezen me echt uitlachen.
# Ik heb mijzelf proberen gerust te stellen met het volgende:    \- Ik ben afgevallen omdat ik in mijn menstruatieweek zit    \- Ik ben afgevallen omdat ik meer pieker over mijn gezondheid, dat kost energie.
# \- Ik heb veel gegeten met kerst, maar de dagen erna erg onregelmatig.
# Soms vergat ik een ontbijt, nam ik een handje m&m's, maar at ik me 's avonds te pletter.
# \- Het is vrij normaal dat je gewicht schommelt    \- Twee jaar geleden toen het zo slecht met je ging ivm angsten viel je ook 4 kg af.
# Toen maakte je je er ook zorgen over.
# 70
# En als je na de kerst 4 kilo was aangekomen...?
# dan had je daar vast ook een andere verklaring voor dan gewoon te veel gegeten...
# Wees blij dat je 1 kilo bent afgevallen (althans ik zou daar blij mee zijn...
# haha!)
# .
# 1 kilo is helemaal niet veel er is heus niet zomaar iets aan de hand!
# Ik ben natuurlijk geen dokter of psych, maar je laatste punt lijkt mij erg aannemelijk als reden waarom je bent afgevallen...
# 71
# Een kilo is niks.
# Ik zou me pas zorgen gaan maken als je wekenlang onbegrepen kilo's blijft afvallen.
# Maar dat is absoluut niet het geval bij jou!
# Wat zei de huisarts?
# 72
# Ha GeorgetteDansLeTabac,      Ik moet even nadenken over je vraag.
# Ik ben bij de huisarts geweest voor het plekje op mijn borst.
# Dat is een pigmentatie....
# Ben wel helemaal gerustgesteld.
# Over mijn hangoog zegt ze dat het waarschijnlijk een 'lokaal probleem' is....
# Ze is wel telkens stellig erin dat ze mij geen 100% zekerheid kan geven...
# Wat mij dus weer onzeker maakt.
# Ik ben gewoon enorm gefixeerd op mijn lichaam de laatste weken...
# Heel naar.
# Wat is me wel afvraag is of het normaal is dat mijn angsten een tijd onder controle waren en ineens lijk ik weer terug bij af...
# terwijl ik wel het huiswerk van de psych doe...
# Eigenlijk zou ik de psychiater moeten bellen en vertellen dat het nu niet goed met me gaat, maar ik durf niet..
# Ben bang dat ik me aanstel..
# 73
# Hing hij altijd al niet iets lager en valt het je de laatste tijd pas op??
# Mijn ene ooglid hangt ook wat lager dan de andere en mijn zus had dat ook voordat ze een ooglidcorrectie uitvoerde.
# 74
# Ik vind het wel logisch dat je nooit 100% zekerheid krijgt wat iets is.
# Een huisarts is geen alwetend orakel, maar een mens die gestudeerd heeft voor arts.
# Hij neemt de anamnese (= voorgeschiedenis van de klachten) af en daaruit komen een aantal mogelijkheden wat het kan zijn.
# De huisarts kiest degene die het meest bij de klachten past, dat heet een differentiaal diagnose.
# De andere mogelijkheden noteert hij voor het geval je klachten niet verbeteren.
# Zo kan hij verder gaan puzzelen.
# Een niet hypochonder zal geen problemen hebben met die slag om de arm, jij helaas wel.
# Een niet hypochonder zal kijken of de klachten gaan verbeteren met de voorgestelde behandelingen of adviezen.
# Maar voor jou is dit eng.
# Want 'er is geen 100% zekerheid.
# ' Helaas kan niemand er wat aan doen jou wel die 100% te geven.
# Jij zal dus zelf eraan moeten werken, maar dat doe je gelukkig al.
# Wat ik je wel zou aanraden is de psychiater te bellen dat het nu niet goed met je gaat.
# Je stelt je niet aan als je dat doet, het is juist sterk om toe te durven geven dat het even niet zo goed gaat.
# De weg naar genezing is er één vol pieken en dalen.
# Nu zit je in een dal, het kan slleen maar beter gaan als je nu aan de bel trekt!
# Sterkte meid!
# !
# 75
# Even een kort antwoord.
# Dat hangend ooglid heb ik niet al mijn hele leven.
# Het is gaan opvallen zo rond het voorjaar toen het niet goed met me ging.
# Maar toen kreeg ik een hersenscan omdat ik duizelingen had, daar kwam niets uit.
# Over dat ooglid maatke ik me toen al helemaal geen zorgen nmeer.
# Het hangt vanaf dat moment altijd wel iets, maar als het minder met mij gaat oid dan hangt hij een stuk duidelijker.
# Het kan natuurlijk zijn dat mijn ooglid al langere tijd iets hangt maar dat het mij niet is opgevallen.
# En als ik goed in mijn vel zit en dus niet met negatieve energie bezig ben staat mijn oog ook redelijk goed...
# dan ziet een leek niet eens dat ie ietsie hangt.
# Ik heb de psychiater gebeld.
# Hij belde mij vrij snel terug en afgesproken is de alprazolam wat te verhogen en a.
# s.
# donderdag eens goed te bekijken hoe nu verder.
# Wel schijnt het inderdaad normaal te zijn dat haptotherapie zo'n inlvoed kan hebben op angst evenals een vakantie.
# Ben ook bij de huisarts geweest om mijn oog te laten zien.
# Ze zag inderdaad duidelijk dat hij hing, maar vond het nog steeds geen reden me door te verwijzen.
# Er zijn meer patienten in de praktijk die het hebben , maar de meesten gaan er niet voor naar de huisarts schijnt.
# Een hangend ooglid zonder andere zaken is geen reden tot zorg.
# Ze zei ook dat ik het al zo lang heb en dat ik me geen zorgen hoef te maken.
# Wel zag ze direct dat ik geestelijk uitgeput ben.
# Ook zij gaf aan dat ik me niet schuldig, slecht, minderwaardig hoef te voelen over even wat meer medicatie.
# Ze vertelde me dat een dal erbij hoort en dat het meestal zo is dat het dal niet zo diep is als de beginsituatie een half jaar geleden en dat ik zal merken dat ik er weer uitkom en dan weer gewoon verder bouw aan herstel.
# Wel sluit ze de mogelijkheid om antidepressiva (fluvoxamine) te gebruiken niet uit, maar dat is aan de psychiater.
# Ik heb dat nl in het verleden , jaar gebruikt en daarop leefde ik lekker.
# Maar om nu daarmee te beginnen is zonde, omdat ik goed bezig ben met de behandeling..
# Alleen een dipje nu......
# 76
# oeps, toch een lang antwoord.
# 77
# Hoi Grietje,      Volgens mij heb je een erg goed gesprek gehad bij de huisarts, fijn!
# Ook over het verloop van de behandeling en de 'dip' waar je nu in zit heeft ze denk ik (voor zover ik dat kan weten natuurlijk), helemaal gelijk.
# Probeer niet te hard voor jezelf te zijn!
# Veel succes, ook alvast voor donderdag!
# 78
# Arme Grietje, wat waardeloos dat de angsten jou zo vaak de baas zijn.
# En ik herken het voor een deel, dus ik weet echt wat er allemaal door je hoofd kan gaan op zo'n moment.
# Het enige wat bij mij echt helpt zijn feiten verzamelen die mijn angsten kunnen weerleggen, en gerustgesteld worden door een persoon die er verstand van heeft en aan wiens oordeel ik veel waarde hecht (in mijn geval mijn huisarts, en zo te lezen heb jij ook wel een fijne huisarts).
# Mijn huisarts heeft me op het hart gedrukt altijd te komen bij angsten, omdat je jezelf helemaal gek kunt maken als je er in je eentje mee rond blijft lopen.
# Ik doe dat dus ook altijd, vaak in de overtuiging dat het nu toch wel echt helemaal mis zal zijn.
# Ik ga vooral naar de huisarts omdat ik er dan in ieder geval vroeg bij ben, mocht het inderdaad foute boel zijn.
# Als mijn huisarts mijn ziekteverdenking tegenspreekt, vraag ik altijd om een heldere toelichting, zodat ik weet waar hij zijn oordeel op baseert.
# Bijvoorbeeld: ik had laatst ook een huidverkleuring op mijn borst, een grote plek van enkele centimeters.
# Ik was ervan overtuigd dat het borstkanker was, omdat ik weet dat huidverkleuring wel degelijk een symptoom kan zijn.
# De huisarts heeft me kunnen geruststellen, het was een hormonale reactie en ik heb er een tijdje vette creme opgesmeerd waardoor het weg is gegaan.
# In dit geval heb ik expliciet aan de huisarts gevraagd, wanneer huidverkleuring dan wél zorgwekkend is.
# Hij legde uit dat dat het geval is bij een grote tumor, die je goed kunt voelen, Bij mij was er geen knobbeltje te voelen en de huid was onder de verkleuring was mooi zacht.
# Dat soort informatie vind ik dus fijn om te weten, voor als ik weer eens een verkleuring zou hebben.
# Verder wil ik nog even inhoudelijk reageren op twee andere angsten die je noemt.
# Ooglid: een spierziekte lijkt me niet aannemelijk, want die kenmerkt zich over het algemeen door krachtverlies in bijvoorbeeld armen of benen, rugklachten of problemen met spraak of slikken.
# Een hangend ooglid komt door ouderdom, vermoeidheid (en dat is niet over met één relaxdagje), stress en ook zoiets simpels als harde contactlenzen, waarbij je telkens aan je ooglid trekt bij het in- en uithalen van de lens.
# Afvallen: uit je berichten blijkt dat je erg veel last hebt van je angsten en dat je er veel mee bezig bent.
# Het is bekend dat lichaam en geest nauw met elkaar verwant zijn en het is heel aannemelijk dat je af bent gevallen als gevolg van alles wat zich in je hoofd afspeelt.
# Je weet vast al wel dat alles erger wordt naarmate je er meer op gefocust bent.
# Maar goed, ik snap op dat het ziektebeeld echt jouw werkelijkheid kan worden, op het moment dat je bepaalde lichamelijke veranderingen bij jezelf waarneemt.
# Pfff lange posting geworden, wie weet kun je er iets uithalen waar je iets aan hebt.
# Veel kracht toegewenst!
# 79
# Ha Panda en Klontje,      Bedankt voor jullie reacties.
# Panda, eigenlijk ben ik wel een beetje geschrokken van je uitleg over die huidverkleuring..
# Het kan dus WEL degelijk een symptoom zijn van borstkanker...
# Maar is het dan niet zo dat het ook warm moet aanvoelen ofzo?
# De huisarts heeft mijn borst bevoeld inderdaad en geen rare dingen gevonden als een knobbel oid.
# ...
# Daar zijn die mensen totaaaal niet mee bezig.
# Heel verstandig!
# 1935
# Her kan iedereen overkomen.
# Je bent iig zo verstandig geweest om een condoom te gebruiken.
# Althans, de intentie was er ;).
# Succes!
# 1936
# Of probeer 'm er uit te spoelen met zo'n intiemdouche, als je die toevalli hebt staan.
# 1937
# > quote:  >  > **[Marels schreef op 05 februari 2011 @ 21:43](    Waarom moet je je daarvoor schamen dan?
# Als het nou een komkommer was die je naar binnen geduwd had en kwijt was, zeg ik ja, terecht dat je je schaamt.
# Maar 't is maar een condoom hoor.
# Hebben ze heus vaker meegemaakt.
# Och een komkommer maken we ook wel eens mee.
# Hoewel, geen komkommer maar wel een winterpeen (in anus vast) en een appel !
# [:sarcastis] een golfbal.
# Ach van alles eigenlijk.
# Tampon en condoom komen ook wel eens voor en dat is nou niet iets om je voor te schamen inderdaad.
# Die hebben we er normaal gesproken zo uit hoor.
# Gewoon naar je huisarts, als je het echt heel erg eng vindt, kan een assistente (die gewend is uitstrijkjes te maken) ook nog wel even voor je kijken.
# 1938
# Eerst aan de wijn?
# Dat klinkt wat ongezond.
# Mensch, je hebt een lijf net als iedereen, da's toch niks om je voor te schamen?
# Denk je dan serieus dat wij als collega's onder elkaar bespreken wie van de bewoners de grootste piemel heeft of wie er tieten tot op de knieĂŤn of enorme vetkwabben heeft?
# Welnee, dat zie je niet eens, daar ben je totaal niet mee bezig.
# 1939
# Je kunt daar met opgeheven hoofd naar binnen lopen hoor, je gebruikt condooms dus je bent heel verstandig.
# En dat niet alleen fotomodellen seks hebben weten ze daar ook wel !
# 1940
# Probeer anders eens goed te persen.
# Als het dan ook nog niet lukt, ga dan echt naar de HAP!
# Als zo'n ding te lang in je vagina blijft zitten, dat kan nooit goed zijn lijkt mij.
# Straks krijg je ontstekingen enz.
# 1941
# Volgens mij kun je meer kwaad dan goed doen door zelf te gaan pielen.
# Als je er met e vinger niet bij kan zou ik echt naar de HAP gaan en zeker niet zelf trucjes gaan proberen!
# 1942
# Ik zou me toch echt drukker maken over Soa's, ongewenste zwangerschap, dan wat de huisarts van me denkt.
# Die man ziet me iedere drie jaar met mijn benen in de beugels.......
# Want blijkbaar doe je dat ook niet.
# 1943
# Als To van 1981 is hoeft ze nog geen uitstrijkjes toch?
# 1944
# nee, maar als ze er toch al voor ligt....
# 1945
# jawel hoor, de eerste krijg je bij 30      Nou ja, ik kan me best voorstellen dat je hier nou niet heel graag mee naar de HAP gaat.
# Wij zijn het condoom ook wel eens kwijtgeraakt in mij en dat is toch best wel kut, letterlijk.
# 1946
# > quote:  >  > **[Marels schreef op 05 februari 2011 @ 22:04](    Als To van 1981 is hoeft ze nog geen uitstrijkjes toch?
# 1947
# Ik zou je niet schamen hoor, ik heb het ook een keer gehad.
# Toen lag ik daar met mijn benen wijd na een woest balkonseksavontuur met toen vriend in de hotelkamer terwijl mijn vriend met een zaklantaarn (sjah) en een heel serieus gezicht dat condoom aan het zoeken was.
# Hij heeft hem wel gevonden (ik kon het zelf niet, ik dacht dat hij er niet inzat, zo diep zat het kennelijk) en eruit gehaald.
# 1948
# Als ze van 81 is wordt ze dus dit jaar pas dertig en is ze nog nooit geweest.
# En toen ik een paar jaar geleden met de benen wijd moest voor het eerst was ik ook zenuwachtig.
# 1949
# > quote:  >  > **[Sunkissed81 schreef op 05 februari 2011 @ 21:54](    Ik ga nu proberen hem eruit te krijgen in de douche, lukt dat niet **dan maar morgen na een paar glazen wijn na de huisartsenpost gaan**.
# Wat denk je dat onaantrekkelijker is ---> A. dikke dijen met een blubberbips en striemen, of B. dikke dijen met een blubberbips, striemen, en een drankkegel?
# !
# 1950
# Ik ben 'em ook weleens kwijt geweest (of wij eigenlijk) en toen zat het helemaal achterin naast de baarmoedermond gefrot.
# Daar voelde ik ook niets van en het was echt even zoeken !
# 1951
# Ik heb dat niet gehad voor ik aan de pil ging.
# En ik zit toch alweer een jaar of zes aan de pil.
# 1952
# Ik zou eerst het bed nog eens goed doorzoeken (of het plafond !
# 1953
# Als je toch naar de HAP moet, zou ik vriendlief meenemen, het is ook zijn schuld !
# 1954
# > quote:  >  > **[Pammie schreef op 05 februari 2011 @ 22:07](    Ik ben 'em ook weleens kwijt geweest (of wij eigenlijk) en toen zat het helemaal achterin naast de baarmoedermond gefrot.
# Daar voelde ik ook niets van en het was echt even zoeken !
# 1955
# Hebben we het vorige week in de auto niet over gehad nee !
# 1956
# A) je hoeft je nergens voor te schamen, een arts heeft wel wat beters te doen dan naar jouw lichaam kijken ( hij kijkt meer in je lichaam zeg maar !
# [;-\)] )      B) kun je met je vinger niet tot je baarmoedermond komen?
# Hij moet daar waarschijnlijk zitten.
# Misschien heeft je vriend langere vingers en kan hij er beter bij.
# Gewoon zo diep mogelijk voelen en een beetje ronddraaien.
# 1957
# > quote:  >  > **[citronella schreef op 05 februari 2011 @ 22:05](    jawel hoor, de eerste krijg je bij 30      Nou ja, ik kan me best voorstellen dat je hier nou niet heel graag mee naar de HAP gaat.
# Wij zijn het condoom ook wel eens kwijtgeraakt in mij en dat is toch best wel kut, letterlijk.
# Ik heb het gelukkig uiteindelijk zelf weer terug gevonden, maar zat toen ook best in de rats        Het is voor 50+, tenzij je zelf een medische reden hebt.
# Maar standaard niet.
# 1958
# Uitstrijkje is vanaf je 30e hoor
# 1959
# > quote:  >  > **[gemini2011 schreef op 05 februari 2011 @ 22:19](    A) je hoeft je nergens voor te schamen, een arts heeft wel wat beters te doen dan naar jouw lichaam kijken ( hij kijkt meer in je lichaam zeg maar !
# [;-\)] )      B) kun je met je vinger niet tot je baarmoedermond komen?
# Hij moet daar waarschijnlijk zitten.
# Misschien heeft je vriend langere vingers en kan hij er beter bij.
# Gewoon zo diep mogelijk voelen en een beetje ronddraaien.
# Dat voel je zelf niet eens goed.
# Je vinger is toch korter dan een staafmixer als het goed is.
# 1960
# Vriendin van mij heeft dit ook meegemaakt.
# Het condoom heeft ze nooit weer gevonden, wel werd negen maanden later een prachtige zoon geboren.....
# 1961
# @TO wat kan het jou schelen wat een arts/verpleger denkt die je eens in je leven ziet en die jou na 10 minuten vergeten is?
# 1962
# > quote:  >  > **[Bim schreef op 05 februari 2011 @ 22:25](    Vriendin van mij heeft dit ook meegemaakt.
# Het condoom heeft ze nooit weer gevonden, wel werd negen maanden later een prachtige zoon geboren.....
# en het condoom is het raam uit gevlogen en er kwam een ooievaar voor terug?
# 1963
# > quote:  >  > **[Bim schreef op 05 februari 2011 @ 22:25](    Vriendin van mij heeft dit ook meegemaakt.
# Het condoom heeft ze nooit weer gevonden, wel werd negen maanden later een prachtige zoon geboren.....
# werd het kind in een condoom geboren?
# 1964
# Persen!!
# 1965
# Als je morgen pas gaat zou ik niet zeggen dat het al vrijdag is gebeurd.
# Ik ben een keer op mijn schouder gevallen en wilde het een dagje aankijken, maar ging toch niet en toen zeiden ze bij de hap dat het geen spoed was omdat ik een dag had gewacht.
# Hij bleek zwaar gekneusd te zijn dus uiteindelijk wel geholpen maar weet niet meer hoe het gegaan is met de kosten, weet wel dat het een nare situatie was en ze overal moeilijk over deden, ook de kosten.
# 1966
# Ksenija, uitstrijkje is echt wel vanaf 30.
# Volgens mij ben jij in de war met het bevolkingsonderzoek borstkanker, dat is geloof ik vanaf 50 (een mammografie dan, een uitstrijkje heeft dan niet zoveel zin !
# [:-P]).
# 1967
# > quote:  >  > **[Hangmat schreef op 05 februari 2011 @ 22:27](    [...
# ]      werd het kind in een condoom geboren?
# !
# [O.
# o].
# 1968
# Nou ksenija ik kan gewoon met mijn wijsvinger naar m'n baarmoedermond hoor.
# In niet opgewonden toestand is de vagina van een vrouw helemaal niet zo diep.
# En voor zover ik weet heb ik geen rare afwijkingen en heb gewoon normale handen.
# Geen kolenschoppen in ieder geval.
# 1969
# > quote:  >  > **[Pammie schreef op 05 februari 2011 @ 22:29](    Ksenija, uitstrijkje is echt wel vanaf 30.
# Volgens mij ben jij in de war met het bevolkingsonderzoek borstkanker, dat is geloof ik vanaf 50 (een mammografie dan, een uitstrijkje heeft dan niet zoveel zin !
# [:-P]).
# Klopt.
# Uitstrijkje is elke 5 jaar vanaf je 30e.
# En of je er wel of niet een 'moet' als je aan de pil gaat verschilt per arts.
# 1970
# Even naar de HAP.
# Je figuur krijgt pas echt een opdonder van negen maanden zwanger zijn en daarna bevallen.
# 1971
# MV, hiermee moet je wel uitkijken, want als je een morning afterpil nodig hebt, zeggen ze misschien wel dat je tot maandag moet wachten om die te halen als je zegt dat je vandaag seks hebt gehad.
# Ik zou er in dit geval niet over liegen.
# 1972
# Lullig, TO.
# Wat anderen zeggen: gewoon naar de HAP bellen en late kijken ernaar.
# Ik ben ook van 1981, dit jaar dus mijn eerste uitstrijkje.
# Maar ik zie er niet tegen op: er is al zo vaak wat inwendig bekeken bij mij...
# !
# [;-\)] Vaginale schimmelinfecties die niet over gingen, inwendige echo's bij zwangerschappen, twee curettages met controles, ontsluiting voelen, bevallen, hechten, controle van de hechtingen, controle van het wondje wat niet dicht wilde...
# Tsja en dat allemaal zonder maat 36.
# Met striemen.
# Jij kan het ook, echt.
# 1973
# Goh....
# dit doet me denken aan mijn allereerste keer.....
# toen was het condoom ook zoek!
# Toen ik even later nar de wc ging en moest persen vanwege een grote boodschap....
# hoorde ik: floeps...
# en vloog het condoom er uit!
# !
# 1974
# > quote:  >  > **[Sgaaaaaaaaaapie_returns schreef op 05 februari 2011 @ 22:06](    [...
# ]        hmm is verplicht voor je met de pil begint volgens mijn huisarts en Gyn  Toen ik met de pil begon op m'n 16e nog niet hoor.
# Ik kreeg mijn eerste uitstrijkje ergens begin 20 toen ik 'n schimmelinfectie had en daarna alleen volgens bevolkingsonderzoek.
# En van de week ben ik voor 't eerst bij de gyn geweest, dus ook dat was niet verplicht voor de pil.
# 1975
# > quote:  >  > **[dubiootje schreef op 05 februari 2011 @ 22:34](    MV, hiermee moet je wel uitkijken, want als je een morning afterpil nodig hebt, zeggen ze misschien wel dat je tot maandag moet wachten om die te halen als je zegt dat je vandaag seks hebt gehad.
# Ik zou er in dit geval niet over liegen.
# precies, ze moeten wel goed weten dat de seks al langer geleden is geweest, want je hebt een grote kans dat de MAP niet werkt.
# TO zou ook meteen doorverwijzing naar een abortuskliniek kunnen vragen, dan krijg je meteen een overtijdbehandeling.
# 1976
# En heb je hem al gevonden?
# Je kunt natuurlijk ook een vaginale douche nemen(met zo'n ding wat daarvoor bestemd is).
# Als er dan niets uit komt, zal hij toch wel ergens anders zijn.
# Je hoeft niet perse naar de HAP hiervoor.
# Hij komt er ook vanzelf wel weer uit hoor.
# Misschien ben je hem wel al verloren toen je naar het toilet ging.
# 1977
# ben je hier een beetje handig mee ?
# !
# [ eetstokjes.
# jpg]( eetstokjes.
# 1978
# > quote:  >  > **[Donkeyshot schreef op 06 februari 2011 @ 09:45](    ben je hier een beetje handig mee ?
# [[afbeelding]( eetstokjes.
# jpg)]  !
# 1979
# Ik ben eens een stukje plastic van een tampon kwijt geweest (te snel ingebracht).
# De HA zei dat je lichaam lichaamsvreemde dingen vanzelf weer eruit werkt, en dat was zo!
# Alleen wordt je niet zwanger van een tamponplasticje natuurlijk.
# 1980
# Uitstrijkje is inderdaad vanaf 30, ik word over een paar maanden 30 en heb afgelopen vrijdag een voorlichtingstijdschrift gekregen over het bevolkingsonderzoek baarmoederhalskanker.
# Over een paar weken krijg ik de daadwerkelijke oproep.
# Toen ik aan de pil ging op mijn 16e heb ik geen uitstrijkje gehad.
# Huisarts heeft toen niet eens mijn bloeddruk opgenomen, gewoon een receptje uitgeschreven.
# 1981
# > quote:  >  > **[Ksenija schreef op 05 februari 2011 @ 22:20](    [...
# ]        Het is voor 50+, tenzij je zelf een medische reden hebt.
# Maar standaard niet.
# Maandagmorgen de huisarts bellen en vragen of je die dag nog lang mag komen (spoed)        Niet waar.
# Uitstrijkje krijg je vanaf je 30ste en dan iedere 5 jaar.
# [ ...
# 1982
# Wat een hilarisch topic!
# :D    Ik zou inderdaad het plafond nog eens checken, of de binnenkant van je dekbedovertrek.
# 1983
# Hoe is het afgelopen?
# Ben je bij de HAP geweest?
# 1984
# Ik ben me toch nieuwschierig..
# is dat condoom nu al terecht??!!
# 1985
# Ben ook benieuwd.
# Ben je nog bij de HA(P) geweest?
# Hoe is het afgelopen?
# 1986
# Even een update      Hij zat toch in mij.
# Zondagavond heeft mijn vriend hem eruit gevist.
# Gelukkig is de HAP me bespaard gebleven.
# 1987
# Heb je nou wel voor de zekerheid een morning after pil genomen??
# Lijkt me wel handig.
# Fijn dat je condoom weer terecht is.
# 1988
# > quote:  >  > **[Sunkissed81 schreef op 08 februari 2011 @ 11:00](    Even een update      Hij zat toch in mij.
# Zondagavond heeft mijn vriend hem eruit gevist.
# Gelukkig is de HAP me bespaard gebleven.
# Mijn vriend was in paniek hij denkt nu dat zijn penis te klein is en dat het condoom daarom afgleed  Je hebt het wel zwaar zeg.
# Lelijk in zonlicht, een vriend met een mini- piemeltje.
# !
# 1989
# Je hebt ook kleinere maten condooms hoor.
# 1990
# > quote:  >  > **[Sunkissed81 schreef op 08 februari 2011 @ 11:00](    Zondagavond heeft mijn vriend hem eruit gevist.
# !
# [ gste_benen1.
# jpg]( man_ontmoet_langste_benen1.
# jpg)    !
# [ ango/files/december/vis2.
# 1991
# > quote:  >  > **[Sunkissed81 schreef op 08 februari 2011 @ 11:00](    Even een update      Hij zat toch in mij.
# Zondagavond heeft mijn vriend hem eruit gevist.
# Gelukkig is de HAP me bespaard gebleven.
# Mijn vriend was in paniek hij denkt nu dat zijn penis te klein is en dat het condoom daarom afgleed        Heb je de morning after pil nog wel gehaald?
# Je bent nu te laat daarvoor, anders toch even langs de huisarts.
# 1992
# verkeerde topic
# 1993
# Hoi meiden,      titel spreekt voor zich, ik ben ongewenst zwanger en ga morgen meteen een afspraak maken bij een abortuskliniek.    Ik ben 28, heb al twee kinderen met mijn man, maar ben ondanks gebruik van voorbehoedsmiddelen toch zwanger geraakt.    We hadden het er nota bene vorige maand na lang twijfelen nog over gehad...willen we nog een kind? We wilden het allebei niet meer en dan nu dit....      Omdat we na de geboorte van de jongste (nu 5) allebei nog zo twijfelden, hadden we geen drastischer maatregelen genomen dan condooms, want ja, ik ga geen spiraal laten zetten om hem een jaar later weer eruit te halen. En zo gingen de twijfels steeds maar door. De pil wil ik absoluut niet meer, die heb ik jaren geslikt, maar werd er (achteraf gezien) emotioneel nogal vlak van.      Pff, die 'positieve' test van gisteren heeft elk spoortje van twijfel in ieder geval compleet weggevaagd. We zeiden allebei meteen NEE.    We krijgen nu net wat vrijheid terug met al wat grotere kinderen, ik ga meer werken, we hebben toch al een hoop babyspullen weggedaan...we zien weer een baby gewoon echt niet meer zitten.      Ik hoop op een beetje steun en ervaringsverhalen, ik heb natuurlijk wel informatie over abortus en overtijdbehandelingen op internet gevonden, maar de theoretische info is toch anders dan ervaringen van andere vrouwen.      groetjes Willeke
# 1994
# Hoi Willeke,    heftige situatie lijkt me!
# Zo'n situatie als deze maakt volgens mij veel discussie los.
# Ik heb er geen ervaring mee, maar zoals je het beschrijft is het een keuze waar jullie beiden achter staan.
# Ik wens je dan ook veel sterkte!
# 1995
# Kan je dit niet beter bij het forum psyche plaatsen?
# Wat heeft dit met je gezondheid te maken?
# 1996
# @Caroline    Nou het is een medische ingreep...
# Willeke, wat heftig!
# In elk geval heel goed dat jullie zo zeker zijn van je zaak.
# Lijkt mij een emotionele achtbaan, waar je nu in komt.
# Sterkte.
# 1997
# Ik hoop dat je sterk in je schoenen staat.
# En dan doel ik niet op de abortus, maar op de reacties hier.
# 1998
# Er is afgelopen week ook een topic over een ongewenste zwangerschap door de moderator naar hier geplaatst.
# Lijkt me dat ze hier dus best goed zit.
# Willeke, sterkte.
# Heb geen ervaring verder.
# 1999
# Veel sterkte toegewenst.
# Jullie zijn er allebei zeker van, dus jullie komen hier goed weer uit.
# authorlist generated
# dictionaries generated
# dictionaries combined
