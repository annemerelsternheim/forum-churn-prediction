# %% [markdown]
# # Analysis of THEMATRIX.csv

# %%
import pandas as pd
import ast
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
MATRIX = pd.read_csv(r"C:\Users\sternheimam\Desktop\my-notebook\THEMATRIX.csv",delimiter=";")

# %% [markdown]
# # AUC analyses

# %% [markdown]
# ## all means and stds for all cells in matrix

# %%
plt.close()
plt.figure(figsize=(20,5))
plt.grid(axis="y")
features=[]
for column in list(MATRIX.columns):
    if column == "Included features":
        for row in MATRIX[column]:
            features.append(row)
    if column!= "Included features":
        col_index = list(MATRIX.columns).index(column)
        means = []
        stds = []
        width = 0.3
        for row in MATRIX[column]:
            N = len(MATRIX[column])
            ind = np.arange(N)
            means.append(np.mean(ast.literal_eval(row)['AUC_scores']))
            stds.append(np.std(ast.literal_eval(row)['AUC_scores']))
        plt.bar(ind+((col_index-2)*width),means,width,yerr=stds)
        for i, v in enumerate(means):
            plt.text(i+((col_index-1.85)*width),v+stds[i]+0.04,"%.3f"%v, rotation=90,ha="center")
plt.ylim(0.5,0.9)
plt.xticks(ind,features,rotation=80)
plt.xlabel("included features")
plt.ylabel("mean AUC")
plt.legend(["churn in 1 month", "churn in 2 months", "churn in 3 months"],loc="upper left")
plt.show()

# %% [raw]
# 3,11: inactivity
# 4,5,8: questions, post length and sentence length
# 9,10,12: MEAN questions, post length and sentence length
# 6,7: sentiment and subjectivity
# 13,14: MEAN sentiment and subjectivity

# %% [raw]
# For most feature combinations, predicting churn is more accurate on a shorter time frame: 3,11 / 4,5,8 / 3,11,13,14/ 3,11,4,5,8/ 13,14,9,10,12/ 3,11/13,14,6,7/ 3,11,13,14,9,10,12/3,11,6,7,9,10,12/ 3,11,6,7,9,10,12,4,5,8/ en nog twee
# However, the opposite also holds for some feature combinations: 9,10,12 / 9,10,12,3,11 / 3,11,6,7,4,5,8 /13,14,6,7,9,10,12 / 6,7,9,10,12,4,5,8 / 3,11,13,14,6,7,4,5,8
# And some tuble up and down, like 13,14/ 6,7/ 3,11,6,7, etc

# %%
for column in list(MATRIX.columns):
    if column!= "Included features":
        means = []
        for row in MATRIX[column]:
            means.append(np.mean(ast.literal_eval(row)['AUC_scores']))
        print column, np.max(means),means.index(np.max(means)), MATRIX['Included features'][means.index(np.max(means))]
# Out:
# Churn in 1 months 0.7999828012010546 27 ((3, 11), (13, 14), (9, 10, 12), (4, 5, 8))
# Churn in 2 months 0.7918320281503329 25 ((3, 11), (13, 14), (6, 7), (9, 10, 12))
# Churn in 3 months 0.7833718907631473 16 ((3, 11), (13, 14), (9, 10, 12))

# %% [raw]
# Worst performing, are:
# the singles (6,7) and (4,5,8) (= both 'local' variables)
# the combination of these (6,7,4,5,8),
# and the combinations (3,11+6,7/4,5,8), and (3,11,6,7,4,5,8) (= all static variables + inactivity)
# also, inacrtivity all by itself (3,11) does not score overly well, although it does score better on its own than combined with any of the 'local' features.
#
# So, let's kick the static features out to see what we end up with, shall we.

# %% [markdown]
# ## all means and stds for cells in matrix not resulting from 'static' features

# %%
def remove_rows_from_matrix(matrix,feature):
    regex = "[^0-9]"+ str(feature) + "[^0-9]"
    new_matrix = matrix[~matrix['Included features'].str.contains(regex)]
    return new_matrix if len(matrix) == len(new_matrix) else remove_rows_from_matrix(new_matrix,feature)

# %%
matrix = MATRIX

for x in [4,5,6,7,8]:
    matrix = remove_rows_from_matrix(matrix,x)

plt.close()
plt.figure(figsize=(10,5))
features=[]
for column in list(matrix.columns):
    if column == "Included features":
        for row in matrix[column]:
            features.append(row)
    if column!= "Included features":
        col_index = list(matrix.columns).index(column)
        means = []
        stds = []
        width = 0.25
        for row in matrix[column]:
            N = len(matrix[column])
            ind = np.arange(N)
            means.append(np.mean(ast.literal_eval(row)['AUC_scores']))
            stds.append(np.std(ast.literal_eval(row)['AUC_scores']))
        plt.bar(ind+((col_index-2)*width),means,width,yerr=stds)
        for i, v in enumerate(means):
            plt.text(i+((col_index-2)*width),v+stds[i]+0.01,"%.3f"%v, rotation=90,ha="center", va = "bottom")
plt.ylim(0.5,0.9)
plt.xticks(ind,features,rotation=80)
plt.xlabel("included features")
plt.ylabel("mean AUC")
#    plt.title(title)
plt.legend(["churn in 1 month", "churn in 2 months", "churn in 3 months"],loc="upper left")
plt.show()

# %% [raw]
# los gezien, is het groepje (9,10,12) het meest succesvol in het voorspellen van churn in 1 2 3 m
# daarna komt (13,14), en tot slot (3,11).
# (3,11)=inactivity maakt tov (9,10,12) (questions words sentences) alle voorspellingen (123 m) iets accurater
# maar, tov (13,14) (sentiment objectivity) helpt inactivity niet altijd even goed: het boost de voorspellingen voor churn in 1 maand behoorlijk, churn in 2 maanden wat minder, en churn in 3 maanden is zelfs slechter te voorspellen!
# het combineren van (13,14) 3n (9,10,12)
# combineren van (9,10,12) en (13,14) veroorzaakt betere voorspellingen voor churn dan wanneer de features los gebruikt worden: de verhoudingen zijn vergelijkbaar met die van (9,10,12), maar de voorspellende waardes zijn hoger
# de voorspellende waardes kunnen nog iets verder omhoog getild worden, voornamelijk voor churn in 2 en 3 maanden, wanneer deze laatste combinatie aangevuld wordt met de inactivity variabele.
# Churn in 1 maand is dan het beste te voorspellen

# %%
for column in list(matrix.columns):
    if column!= "Included features":
        means = []
        for row in matrix[column]:
            means.append(np.mean(ast.literal_eval(row)['AUC_scores']))
        print column, np.max(means),means.index(np.max(means)), matrix['Included features'].reset_index(drop=True)[means.index(np.max(means))]
# Out:
# Churn in 1 months 0.7954354562302764 6 ((3, 11), (13, 14), (9, 10, 12))
# Churn in 2 months 0.7824232724404696 6 ((3, 11), (13, 14), (9, 10, 12))
# Churn in 3 months 0.7833718907631473 6 ((3, 11), (13, 14), (9, 10, 12))

# %% [markdown]
# ## the opposite: only from cells resulting from static features

# %%
matrix = MATRIX

for x in [9,10,12,13,14]:
    matrix = remove_rows_from_matrix(matrix,x)

plt.close()
plt.figure(figsize=(10,5))
features=[]
for column in list(matrix.columns):
    if column == "Included features":
        for row in matrix[column]:
            features.append(row)
    if column!= "Included features":
        col_index = list(matrix.columns).index(column)
        means = []
        stds = []
        width = 0.25
        for row in matrix[column]:
            N = len(matrix[column])
            ind = np.arange(N)
            means.append(np.mean(ast.literal_eval(row)['AUC_scores']))
            stds.append(np.std(ast.literal_eval(row)['AUC_scores']))
        plt.bar(ind+((col_index-2)*width),means,width,yerr=stds)
        for i, v in enumerate(means):
            plt.text(i+((col_index-2)*width),v+stds[i]+0.01,"%.3f"%v, rotation=90,ha="center",va="bottom")
plt.ylim(0.5,0.9)
plt.xticks(ind,features,rotation=80)
plt.xlabel("included features")
plt.ylabel("mean AUC")
#    plt.title(title)
plt.legend(["churn in 1 month", "churn in 2 months", "churn in 3 months"],loc="upper left")

plt.show()

# %% [raw]
# In general, sentiment and sentencestuff have virtually no predictive value by themselves. Neither do they predict anything together. Only inactivity is able to lift the spirits.
#
# predicting churn in 1 or 2 monthsis most accurate if only inactivity is used
# gets a little worse when (6,7) is added (sentiment etc), and a little more worse when (4,5,8) is added (sentence length etc). A combination of all three makes the prediction even less accurate.
# predicting churn in 3 months is not affected much by changes in these static values. (perhaps because the values of 3 months before your leave do not matter much, individually: perhaps they vary more?)

# %%
for column in list(matrix.columns):
    if column!= "Included features":
        means = []
        for row in matrix[column]:
            means.append(np.mean(ast.literal_eval(row)['AUC_scores']))
        print column, np.max(means),means.index(np.max(means)), matrix['Included features'].reset_index(drop=True)[means.index(np.max(means))]
# Out:
# Churn in 1 months 0.6381206696180834 0 ((3, 11))
# Churn in 2 months 0.6110645716433636 0 ((3, 11))
# Churn in 3 months 0.5843245009048854 4 ((3, 11), (4, 5, 8))

# %% [markdown]
# ## means and stds only for cells in matrix corresponding to some feature

# %%
for x in [(3,11),(4,5,8),(9,10,12),(6,7),(13,14)]:
    regex = str(x)
    small_MATRIX = MATRIX[MATRIX['Included features'].str.contains(regex)]
    
    title = "features contain "+str(x)
    
    plt.close()
    plt.figure(figsize=(20,5))
    features=[]
    for column in list(small_MATRIX.columns):
        if column == "Included features":
            for row in small_MATRIX[column]:
                features.append(row)
        if column!= "Included features":
            col_index = list(small_MATRIX.columns).index(column)
            means = []
            stds = []
            width = 0.25
            for row in small_MATRIX[column]:
                N = len(small_MATRIX[column])
                ind = np.arange(N)
                means.append(np.mean(ast.literal_eval(row)['AUC_scores']))
                stds.append(np.std(ast.literal_eval(row)['AUC_scores']))
            plt.bar(ind+((col_index-2)*width),means,width,yerr=stds)
            for i, v in enumerate(means):
                plt.text(i+((col_index-1.9)*width),v+stds[i]+0.01,"%.3f"%v, rotation=90,ha="center",va="bottom")
    plt.ylim(0.5,0.9)
    plt.xticks(ind,features,rotation=80)
    plt.xlabel("included features")
    plt.ylabel("mean AUC")
    plt.title(title)
    plt.legend(["churn in 1 month", "churn in 2 months", "churn in 3 months"],loc="upper left")
    plt.show()
# Out:
# C:\Users\sternheimam\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [raw]
# When features contain (9,10,12), You always get pretty good predictions. Just using (9,10,12) already gives accuracies of  0.7 (churn 1) and 0.73 (churn 2,3). Adding (3,11 / inactivity) increases accuracy to 0.73 (c1) 0.75 (c2) and 0.76 (c3). Combining with (13,14 /sentiment mean) has similar effects, except c1 is even more accurately predicted. Combining with static features ((6,7) or (4,5,8)) increases accuracy for c1, but decreases for c2 and c3.
#
# combining both dynamic features with inactivity gives the best scores until now: 0.8 for c1, 0.78 for c2 and c3.
# Substituting any of the features with a static feature decreases the predictive accuracy. Adding (6,7 /static sentiment) increases c2 accuracy, but decreases c1 and c3. Adding (4,5,8 / static sentence stuff) increases c1 accuracy and decreses c2 and c3 accuracy. Substituting dynamic sentiment for any of the static variables  decreases accuracy. Combining all features gives the best possible accuracies for c1 and c2, and c3 is not far away from its best option.
# However, I would recommend ignoring the static features, as the model will not significantly improve if they ARE used, but will become more complex.

# %% [markdown]
# # making a nice overview of relevant information

# %%
matrix = MATRIX

# %%
new_matrix = pd.DataFrame()
for column in list(matrix.columns):
    churnvalues = []
    learning_rate = []
    n_estimators = []
    max_depth = []
    means = []
    stds = []
    if column == "Included features":
        for row in matrix[column]:
            for n in range(4):
                churnvalues.append(row)    
    if column!= "Included features":
        for row in matrix[column]:
            row = ast.literal_eval(row)
            means.append(np.mean(row['AUC_scores']))
            stds.append(np.std(row['AUC_scores']))
            learning_rate.append(row['parameter_settings']['learning_rate'])
            n_estimators.append(row['parameter_settings']['n_estimators'])
            max_depth.append(row['parameter_settings']['max_depth'])
        for i in range(len(matrix)):
            churnvalues.append(r"%.3f $\pm$ %.3f" %(means[i],stds[i]))
            for v in [learning_rate,n_estimators,max_depth]:
                churnvalues.append(v[i])
    new_matrix[column]=churnvalues
    new_matrix["values"]=[item for sublist in [["AUC","learning\_rate", "n\_estimators", "max\_depth"] for i in range(len(matrix))] for item in sublist]

# %%
new_matrix.to_csv("shortmatrix.csv", sep="&",index=False)

# %% [markdown]
# # significance of differences between AUC scores

# %%
matrix = MATRIX

# %%
significance_matrix = pd.DataFrame()
churnvalues = []
for column in list(matrix.columns):
    scores = []
    if column == "Included features":
        for row in matrix[column]:
            churnvalues.append(row)
    if column != "Included features":
        for row in matrix[column]:
            row = ast.literal_eval(row)
            scores.append(row['AUC_scores'])
        for t1 in scores:
            c = []
            for t2 in scores:
                r = []
                _,r = stats.ttest_rel(t1, t2)
                c.append(r)
            significance_matrix[churnvalues[scores.index(t1)]]=c
        D = dict()
        for i,v in enumerate(list(significance_matrix.columns)):
            D[i] = v
        significance_matrix.rename(D,inplace=True)
        plot_significance_matrix(significance_matrix,column)

# %%
def plot_significance_matrix(dataframe,column):
    plt.close()
    plt.figure(figsize=(20,20))
    mask = np.zeros_like(dataframe, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    if column == "Churn in 1 months":
        color = "Blues_r"
    elif column == "Churn in 2 months":
        color = "Oranges_r"
    else:
        color = "Greens_r"
    cmap = sbn.color_palette(color)
    sbn.heatmap(dataframe, mask=mask, cmap=cmap,square=True,cbar_kws = {"shrink":.5},vmin=0.0,vmax=0.06,annot=True,fmt='.3f')
    plt.title(column)
    plt.show()
